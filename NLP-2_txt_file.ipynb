# %%
# %%writefile first.txt
#
# Hellow Sir What Are you doing ?
# Hellow
# Yes You are so smart okey Thanks for advise but hellow jitendra.
# Out:
# Writing first.txt

# %%
file = open('first.txt')

# %%
file
# Out:
# <_io.TextIOWrapper name='first.txt' mode='r' encoding='UTF-8'>

# %%
file.read()
# Out:
# ''

# %%
file.seek(0)

# besically that is reset the index and after you run your txt file
# Out:
# 0

# %%
file.read()
# Out:
# '\nHellow Sir What Are you doing ?\nHellow \nYes You are so smart okey Thanks for advise but hellow jitendra.'

# %%
file.seek(0)

var = file.read()
print(var)
# Out:
# Hellow Sir What Are you doing ?
# Hellow
# Yes You are so smart okey Thanks for advise but hellow jitendra.

# %%
file.close()

# %%
file = open('first.txt')

# %%
file.readlines()
# Out:
# ['\n',
#  'Hellow Sir What Are you doing ?\n',
#  'Hellow \n',
#  'Yes You are so smart okey Thanks for advise but hellow jitendra.']

# %%
file.seek(0)
# Out:
# 0

# %%
line = file.readlines()

# %%
line
# Out:
# ['\n',
#  'Hellow Sir What Are you doing ?\n',
#  'Hellow \n',
#  'Yes You are so smart okey Thanks for advise but hellow jitendra.']
