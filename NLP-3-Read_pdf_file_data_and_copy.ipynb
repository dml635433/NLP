# %%
# !pip install PyPDF2

# %%
from google.colab import files
import PyPDF2

# %%
upload = files.upload()
# Out:
#      <input type="file" id="files-21a1bddb-c94a-40e2-ac82-9e14e453d8a2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-21a1bddb-c94a-40e2-ac82-9e14e453d8a2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving DBMS Notes.pdf to DBMS Notes.pdf

# %%
# !ls
# Out:
# 'DBMS Notes.pdf'   Hariom_ticket.pdf   sample_data

# %%
myfiles = open('DBMS Notes.pdf',mode="rb")

# %%
pdf_reader = PyPDF2.PdfFileReader(myfiles)

# Read file

# %%
pdf_reader.numPages

# how many pages in pdf file that is count
# Out:
# 28

# %%
page_one = pdf_reader.getPage(0)

# get a page index start 0

# %%
print(page_one.extractText())

# extractText your pdf o index page
# Out:
# Characteristics of the Database Approach
#
#
#
# A number of characteristics distinguish the database approach from the much older approach of
# writing customized programs to access data stored in files. In traditional file processing, each user
# defines and implements the files needed for a specific softw
# are application as part of
# programming the application.
#
#
#
# For example, one user, the grade reporting office, may keep files on students and their grades.
#
# applica
#
# payments. Although both users are interested in data about students, each user maintains separate
# files
#
# and programs to manipulate these files
#
# because each requires some
#
# data not available
#
# space and in redundant efforts to maintain common up
# -
# to
# -
# date data.
#
#
#
# In the database approach, a single repository maintains data that is
# defined once and then accessed
# by various users repeatedly through queries, transactions, and application programs. The main
# ...

# %%
myfiles.close()

# %%
## Copy Data One PDF File to Another PDF File

# %%
new_file = open("DBMS Notes.pdf",mode="rb")

# %%
read_file = PyPDF2.PdfFileReader(new_file)

# %%
get_file_number = read_file.numPages

# %%
get_file_number
# Out:
# 28

# %%
get_page_number = read_file.getPage(0)

# %%
print(get_page_number.extractText())
# Out:
# Characteristics of the Database Approach
#
#
#
# A number of characteristics distinguish the database approach from the much older approach of
# writing customized programs to access data stored in files. In traditional file processing, each user
# defines and implements the files needed for a specific softw
# are application as part of
# programming the application.
#
#
#
# For example, one user, the grade reporting office, may keep files on students and their grades.
#
# applica
#
# payments. Although both users are interested in data about students, each user maintains separate
# files
#
# and programs to manipulate these files
#
# because each requires some
#
# data not available
#
# space and in redundant efforts to maintain common up
# -
# to
# -
# date data.
#
#
#
# In the database approach, a single repository maintains data that is
# defined once and then accessed
# by various users repeatedly through queries, transactions, and application programs. The main
# ...

# %%
pdf_writer = PyPDF2.PdfFileWriter()

# %%
pdf_writer.addPage(first_one)

# %%
pdf_output = open("DBMS.pdf",mode="wb")

# %%
pdf_writer.write(pdf_output)

# %%
pdf_output.close()

# %%
p.close()


# Ending files all files..

# %%
new_file = open("DBMS.pdf",mode="rb")

# %%
pdf_reader = PyPDF2.PdfFileReader(new_file)

# %%
pdf_reader.numPages
# Out:
# 1

# %%
get_pages = pdf_reader.getPage(0)

# %%
print(get_pages.extractText())
# Out:
# Characteristics of the Database Approach
#
#
#
# A number of characteristics distinguish the database approach from the much older approach of
# writing customized programs to access data stored in files. In traditional file processing, each user
# defines and implements the files needed for a specific softw
# are application as part of
# programming the application.
#
#
#
# For example, one user, the grade reporting office, may keep files on students and their grades.
#
# applica
#
# payments. Although both users are interested in data about students, each user maintains separate
# files
#
# and programs to manipulate these files
#
# because each requires some
#
# data not available
#
# space and in redundant efforts to maintain common up
# -
# to
# -
# date data.
#
#
#
# In the database approach, a single repository maintains data that is
# defined once and then accessed
# by various users repeatedly through queries, transactions, and application programs. The main
# ...
