# %%
print("Hi jitendra singh")
# Out:
# Hi jitendra singh

# %%
def hello(a,b):
  c = a+b
  return c
d = hello(8,6)
d
# Out:
# 14

# %%
name = "Your Laptop is not a great"

print("Okey : ",name)
print("Okey : "+name)

print("Sure {}".format(name))

print(f"Achha {name}")
# Out:
# Okey :  Your Laptop is not a great
# Okey : Your Laptop is not a great
# Sure Your Laptop is not a great
# Achha Your Laptop is not a great

# %%
list_1 = ['a','b','c','d','e']

list_1[0]

print(f"\n value of list_1 = {list_1[0]}")
# Out:
#  value of list_1 = a

# %%
dict1 = {"dic" : 10, "dic1" : 20, "dic2" : 30}

print(f"value of dic : {dict1['dic']}")
print(f"value of dic : {dict1['dic2']}")
# Out:
# value of dic : 10
# value of dic : 30

# %%
data = [("Name" , "Branch" , "Price" , "Year"),
        ("Mohan" , "Ds" , '1000' , "2000"),
        ("jitendra" , "CMS" , "500", "2021"),
        ("Raj" , "TMT" , "852" , "3596")]


data
# Out:
# [('Name', 'Branch', 'Price', 'Year'),
#  ('Mohan', 'Ds', '1000', '2000'),
#  ('jitendra', 'CMS', '500', '2021'),
#  ('Raj', 'TMT', '852', '3596')]

# %%
print(f"\ncollega data is {data[0]}")

print(f"\n Some Data is : {data[1]}")
# Out:
# collega data is ('Name', 'Branch', 'Price', 'Year')
#
#  Some Data is : ('Mohan', 'Ds', '1000', '2000')

# %%
for college in data:
  print("\n",college[0])
  print("\n",college[3])
# Out:
#  Name
#
#  Year
#
#  Mohan
#
#  2000
#
#  jitendra
#
#  2021
#
#  Raj
#
#  3596

# %%
data
# Out:
# [('Name', 'Branch', 'Price', 'Year'),
#  ('Mohan', 'Ds', '1000', '2000'),
#  ('jitendra', 'CMS', '500', '2021'),
#  ('Raj', 'TMT', '852', '3596')]

# %%
for Name , Branch , Price , Year in data :
  print(f"{Name:{10}} {Branch:{20}} {Price:{15}} {Year:{20}}")
# Out:
# Name       Branch               Price           Year
# Mohan      Ds                   1000            2000
# jitendra   CMS                  500             2021
# Raj        TMT                  852             3596
